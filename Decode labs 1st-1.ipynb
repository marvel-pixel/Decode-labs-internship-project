# %%
# Import libraries
import pandas as pd
import os
import numpy as np

# Load the Excel dataset
df = pd.read_excel(r"C:\Users\user\Documents\data analytics daily challenge/Decodelabs/Dataset for Data Analytics decode.xlsx")

# Display the first five rows
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
# ==========================================
# 1. CHECK DATA INFORMATION
# ==========================================

print("\nDataset Information:")
print(df.info())

print("\nDataset Shape:")
print(df.shape)

# ==========================================
# 2. IDENTIFY MISSING VALUES
# ==========================================

print("\nMissing Values:")
print(df.isnull().sum())

# Display rows containing missing values
missing_rows = df[df.isnull().any(axis=1)]
print("\nRows with Missing Values:")
print(missing_rows)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   object
#  1   Date             1200 non-null   datetime64[ns]
#  2   CustomerID       1200 non-null   object
#  3   Product          1200 non-null   object
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   object
#  7   PaymentMethod    1200 non-null   object
#  8   OrderStatus      1200 non-null   object
#  9   TrackingNumber   1200 non-null   object
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    object
#  12  ReferralSource   1200 non-null   object
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(9)
# memory usage: 131.4+ KB
# None
#
# ...

# %%
# ==========================================
# 1. CHECK DATA INFORMATION
# ==========================================

print("\nDataset Information:")
print(df.info())

print("\nDataset Shape:")
print(df.shape)

# ==========================================
# 2. IDENTIFY MISSING VALUES
# ==========================================

print("\nMissing Values:")
print(df.isnull().sum())

# Display rows containing missing values
missing_rows = df[df.isnull().any(axis=1)]
print("\nRows with Missing Values:")
print(missing_rows)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   object
#  1   Date             1200 non-null   datetime64[ns]
#  2   CustomerID       1200 non-null   object
#  3   Product          1200 non-null   object
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   object
#  7   PaymentMethod    1200 non-null   object
#  8   OrderStatus      1200 non-null   object
#  9   TrackingNumber   1200 non-null   object
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    object
#  12  ReferralSource   1200 non-null   object
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(9)
# memory usage: 131.4+ KB
# None
#
# ...

# %%
# ==========================================
# 5. CORRECT DATA FORMATS
# ==========================================

# Clean column names by removing extra spaces
if hasattr(df.columns, "str"):
    df.columns = [col.strip() if isinstance(col, str) else col for col in df.columns]

# Identify text-like columns dynamically
text_cols = [col for col in df.columns if df[col].dtype == "object"]

# Remove leading/trailing spaces from text columns
for col in text_cols:
    df[col] = df[col].astype("string").str.strip()

# Convert date-like columns
for col in df.columns:
    if "date" in col.lower():
        df[col] = pd.to_datetime(df[col], errors="coerce")

# Convert numeric columns stored as text
for col in df.columns:
    if df[col].dtype == "object":
        try:
            df[col] = pd.to_numeric(df[col], errors="coerce")
        except Exception:
            pass

# %%
# 6. STANDARDIZE TEXT
# =========================

# Standardize text in categorical columns if the list exists
if 'categorical_cols' in locals() and categorical_cols:
    for col in categorical_cols:
        if col in df.columns:
            df[col] = df[col].fillna("").astype("string").str.strip().str.title()

# ==========================================
# 7. VERIFY CLEANED DATA
# ==========================================

print("\nFinal Dataset Information:")
print(df.info())

print("\nSummary Statistics:")
print(df.describe(include='all'))

print("\nFirst Five Rows:")
print(df.head())

# ==========================================
# 8. SAVE CLEANED DATASET
# ==========================================

output_path = r"C:\Users\user\Documents\data analytics daily challenge\Decodelabs\Cleaned_Dataset.xlsx"
df.to_excel(output_path, index=False)

print("\nData cleaning completed successfully!")
print(f"Cleaned dataset saved as '{output_path}'")
print(df.head())
# Out:
# Final Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   string
#  1   Date             1200 non-null   datetime64[ns]
#  2   CustomerID       1200 non-null   string
#  3   Product          1200 non-null   string
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   string
#  7   PaymentMethod    1200 non-null   string
#  8   OrderStatus      1200 non-null   string
#  9   TrackingNumber   1200 non-null   string
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    string
#  12  ReferralSource   1200 non-null   string
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), string(9)
# memory usage: 131.4 KB
# None
#
# ...
